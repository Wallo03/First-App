# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# Use skiprows to choose starting point and nrows to choose number of rows
#df1 = df[ (df['Province/State'] == 'Ontario')]
#df1 = df[ (df['Reported Date'] == '2022')]

#### df1[df1['Province/State'] == 'Ontario']

# %%
df = pd.read_csv('Dati.csv')
df = df[ (df['PHU_NAME'] == 'TORONTO')]
#df.rename(columns={'Reported Date':'Date'},inplace=True)
#df = df.iloc[696:]
df
# Out:
#          _id            FILE_DATE PHU_NAME  PHU_NUM  ACTIVE_CASES  \
# 29        30  2020-04-01T00:00:00  TORONTO   3895.0           430
# 63        64  2020-04-02T00:00:00  TORONTO   3895.0           424
# 97        98  2020-04-03T00:00:00  TORONTO   3895.0           479
# 131      132  2020-04-04T00:00:00  TORONTO   3895.0           491
# 165      166  2020-04-05T00:00:00  TORONTO   3895.0           535
# ...      ...                  ...      ...      ...           ...
# 32941  32942  2022-11-27T00:00:00  TORONTO   3895.0          1715
# 32975  32976  2022-11-28T00:00:00  TORONTO   3895.0          1685
# 33009  33010  2022-11-29T00:00:00  TORONTO   3895.0          1678
# 33043  33044  2022-11-30T00:00:00  TORONTO   3895.0          1721
# 33077  33078  2022-12-01T00:00:00  TORONTO   3895.0          1751
#
#        RESOLVED_CASES  DEATHS  ARCHIVED_RESOLVED_CASES  ARCHIVED_DEATHS
# 29                205       0                    205.0              0.0
# ...

# %%
lista = ['ACTIVE_CASES', 'RESOLVED_CASES', 'DEATHS']
plt.figure(figsize=(18,10))
ax = plt.gca()
#for i in lista:
for i in lista:
    df.plot(kind='line', x='FILE_DATE', y=i, ax=ax)
